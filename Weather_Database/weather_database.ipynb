# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 786

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descr = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": city_descr,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 1 | labuhan
# Processing Record 3 of Set 1 | hirara
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | kismayo
# Processing Record 6 of Set 1 | tshane
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | shebekino
# Processing Record 11 of Set 1 | voznesenskoye
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | muli
# Processing Record 14 of Set 1 | coihaique
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | mackay
# Processing Record 20 of Set 1 | rocha
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | ponnani
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | paita
# Processing Record 25 of Set 1 | mirnyy
# Processing Record 26 of Set 1 | havre-saint-pierre
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | izumo
# Processing Record 29 of Set 1 | grand gaube
# Processing Record 30 of Set 1 | pangnirtung
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | valle del guamuez
# Processing Record 34 of Set 1 | ostrovnoy
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | vitim
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | lodja
# Processing Record 42 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | yulara
# Processing Record 45 of Set 1 | berlevag
# Processing Record 46 of Set 1 | kavaratti
# Processing Record 47 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaqortoq
# Processing Record 49 of Set 1 | byron bay
# Processing Record 50 of Set 1 | tokur
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 2 | puerto cortes
# City not found. Skipping...
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 2 | kurtamysh
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | kumluca
# Processing Record 11 of Set 2 | santa cruz
# Processing Record 12 of Set 2 | aktash
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | karpathos
# Processing Record 15 of Set 2 | faanui
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | sirjan
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | avera
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | san cristobal
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | marsh harbour
# Processing Record 26 of Set 2 | oranjestad
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | krasnoselkup
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | northam
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | ylivieska
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | vaini
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | cidreira
# Processing Record 40 of Set 2 | paamiut
# Processing Record 41 of Set 2 | pisco
# Processing Record 42 of Set 2 | luanda
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | council bluffs
# Processing Record 45 of Set 2 | fallon
# Processing Record 46 of Set 2 | kruisfontein
# Processing Record 47 of Set 2 | llata
# Processing Record 48 of Set 2 | acapulco
# Processing Record 49 of Set 2 | biak
# Processing Record 50 of Set 2 | lasa
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | taldan
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | san juan
# Processing Record 6 of Set 3 | tombouctou
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | roma
# Processing Record 9 of Set 3 | chifeng
# Processing Record 10 of Set 3 | artyom
# Processing Record 11 of Set 3 | san francisco
# Processing Record 12 of Set 3 | semey
# Processing Record 13 of Set 3 | sulat
# Processing Record 14 of Set 3 | lujan
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | nakhon phanom
# Processing Record 17 of Set 3 | north platte
# Processing Record 18 of Set 3 | adrar
# Processing Record 19 of Set 3 | luan
# Processing Record 20 of Set 3 | lagoa
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | norman wells
# Processing Record 23 of Set 3 | birecik
# Processing Record 24 of Set 3 | victoria
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | new norfolk
# Processing Record 28 of Set 3 | port said
# Processing Record 29 of Set 3 | urengoy
# Processing Record 30 of Set 3 | puerto baquerizo moreno
# Processing Record 31 of Set 3 | hamilton
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | sanary-sur-mer
# Processing Record 34 of Set 3 | celano
# Processing Record 35 of Set 3 | yellowknife
# Processing Record 36 of Set 3 | flinders
# Processing Record 37 of Set 3 | solnechnyy
# Processing Record 38 of Set 3 | letlhakane
# Processing Record 39 of Set 3 | waingapu
# Processing Record 40 of Set 3 | klaksvik
# Processing Record 41 of Set 3 | ranong
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | lorengau
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | saint-augustin
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | dumas
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | kudirkos naumiestis
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | harper
# Processing Record 7 of Set 4 | kulhudhuffushi
# Processing Record 8 of Set 4 | mizdah
# Processing Record 9 of Set 4 | vila do maio
# Processing Record 10 of Set 4 | marawi
# Processing Record 11 of Set 4 | broome
# Processing Record 12 of Set 4 | isangel
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | rottenmann
# Processing Record 15 of Set 4 | padang
# Processing Record 16 of Set 4 | guantanamo
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 4 | koumac
# Processing Record 20 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 21 of Set 4 | taman
# Processing Record 22 of Set 4 | kedarnath
# City not found. Skipping...
# Processing Record 23 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 24 of Set 4 | bluff
# Processing Record 25 of Set 4 | saint anthony
# Processing Record 26 of Set 4 | buchanan
# Processing Record 27 of Set 4 | honiara
# Processing Record 28 of Set 4 | bereda
# Processing Record 29 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 30 of Set 4 | linhares
# Processing Record 31 of Set 4 | bredasdorp
# Processing Record 32 of Set 4 | pudozh
# Processing Record 33 of Set 4 | barcelona
# Processing Record 34 of Set 4 | semporna
# Processing Record 35 of Set 4 | whitehorse
# Processing Record 36 of Set 4 | aghavnadzor
# Processing Record 37 of Set 4 | malatya
# Processing Record 38 of Set 4 | ramhormoz
# Processing Record 39 of Set 4 | acarau
# Processing Record 40 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | kahului
# Processing Record 42 of Set 4 | mbanza-ngungu
# Processing Record 43 of Set 4 | mecca
# Processing Record 44 of Set 4 | santa isabel
# Processing Record 45 of Set 4 | mehamn
# Processing Record 46 of Set 4 | babushkin
# Processing Record 47 of Set 4 | acajutla
# Processing Record 48 of Set 4 | coahuayana
# Processing Record 49 of Set 4 | half moon bay
# Processing Record 50 of Set 4 | bowen
# Processing Record 1 of Set 5 | siderno
# Processing Record 2 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 3 of Set 5 | amapa
# Processing Record 4 of Set 5 | buala
# Processing Record 5 of Set 5 | cramlington
# Processing Record 6 of Set 5 | barrow
# Processing Record 7 of Set 5 | mersing
# Processing Record 8 of Set 5 | san ignacio
# Processing Record 9 of Set 5 | vila velha
# Processing Record 10 of Set 5 | royan
# Processing Record 11 of Set 5 | svetlaya
# Processing Record 12 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 5 | itarema
# Processing Record 14 of Set 5 | geraldton
# Processing Record 15 of Set 5 | vao
# Processing Record 16 of Set 5 | swan river
# Processing Record 17 of Set 5 | arraial do cabo
# Processing Record 18 of Set 5 | butembo
# Processing Record 19 of Set 5 | ihosy
# Processing Record 20 of Set 5 | emba
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | tongren
# Processing Record 23 of Set 5 | benghazi
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | yumen
# Processing Record 26 of Set 5 | lokoja
# Processing Record 27 of Set 5 | samarai
# Processing Record 28 of Set 5 | cap malheureux
# Processing Record 29 of Set 5 | ketchikan
# Processing Record 30 of Set 5 | gamba
# Processing Record 31 of Set 5 | kichera
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | cherskiy
# Processing Record 34 of Set 5 | conceicao da barra
# Processing Record 35 of Set 5 | kodiak
# Processing Record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 5 | san andres
# Processing Record 38 of Set 5 | kalevala
# Processing Record 39 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 5 | olutanga
# Processing Record 41 of Set 5 | nikolskoye
# Processing Record 42 of Set 5 | udachnyy
# Processing Record 43 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 5 | tigil
# Processing Record 45 of Set 5 | guerrero negro
# Processing Record 46 of Set 5 | sao felix do xingu
# Processing Record 47 of Set 5 | tungor
# Processing Record 48 of Set 5 | aasiaat
# Processing Record 49 of Set 5 | bendigo
# Processing Record 50 of Set 5 | bandarbeyla
# Processing Record 1 of Set 6 | ugra
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | zonguldak
# Processing Record 4 of Set 6 | sao joao da barra
# Processing Record 5 of Set 6 | tunxi
# City not found. Skipping...
# Processing Record 6 of Set 6 | avarua
# Processing Record 7 of Set 6 | longyearbyen
# Processing Record 8 of Set 6 | eureka
# Processing Record 9 of Set 6 | pevek
# Processing Record 10 of Set 6 | portland
# Processing Record 11 of Set 6 | pallasovka
# Processing Record 12 of Set 6 | miri
# Processing Record 13 of Set 6 | orocue
# Processing Record 14 of Set 6 | sesheke
# Processing Record 15 of Set 6 | maniitsoq
# Processing Record 16 of Set 6 | mananara
# Processing Record 17 of Set 6 | comodoro rivadavia
# Processing Record 18 of Set 6 | tautira
# Processing Record 19 of Set 6 | praia da vitoria
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | labrea
# Processing Record 22 of Set 6 | skjervoy
# Processing Record 23 of Set 6 | margate
# Processing Record 24 of Set 6 | los llanos de aridane
# Processing Record 25 of Set 6 | torres
# Processing Record 26 of Set 6 | saldanha
# Processing Record 27 of Set 6 | saint-francois
# Processing Record 28 of Set 6 | kaseda
# Processing Record 29 of Set 6 | oyskhara
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | xiaoweizhai
# Processing Record 32 of Set 6 | severo-kurilsk
# Processing Record 33 of Set 6 | bage
# Processing Record 34 of Set 6 | boa vista
# Processing Record 35 of Set 6 | kapoeta
# Processing Record 36 of Set 6 | poum
# Processing Record 37 of Set 6 | srednekolymsk
# Processing Record 38 of Set 6 | savannah bight
# Processing Record 39 of Set 6 | nizhniy tsasuchey
# Processing Record 40 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 6 | oktyabrskiy
# Processing Record 42 of Set 6 | grand baie
# Processing Record 43 of Set 6 | rokytne
# Processing Record 44 of Set 6 | iracoubo
# Processing Record 45 of Set 6 | abu samrah
# Processing Record 46 of Set 6 | abu dhabi
# Processing Record 47 of Set 6 | laguna
# Processing Record 48 of Set 6 | pochutla
# Processing Record 49 of Set 6 | omsukchan
# Processing Record 50 of Set 6 | kiboga
# Processing Record 1 of Set 7 | ribeira grande
# Processing Record 2 of Set 7 | jalu
# Processing Record 3 of Set 7 | ngunguru
# Processing Record 4 of Set 7 | morristown
# Processing Record 5 of Set 7 | shaunavon
# Processing Record 6 of Set 7 | la asuncion
# Processing Record 7 of Set 7 | tynda
# Processing Record 8 of Set 7 | chuy
# Processing Record 9 of Set 7 | dandong
# Processing Record 10 of Set 7 | novobirilyussy
# Processing Record 11 of Set 7 | kenai
# Processing Record 12 of Set 7 | nemuro
# Processing Record 13 of Set 7 | dakar
# Processing Record 14 of Set 7 | khandyga
# Processing Record 15 of Set 7 | leshukonskoye
# Processing Record 16 of Set 7 | bolama
# Processing Record 17 of Set 7 | golden
# Processing Record 18 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 19 of Set 7 | batan
# Processing Record 20 of Set 7 | koregaon
# Processing Record 21 of Set 7 | peniche
# Processing Record 22 of Set 7 | richards bay
# Processing Record 23 of Set 7 | ust-kut
# Processing Record 24 of Set 7 | riga
# Processing Record 25 of Set 7 | balgazyn
# Processing Record 26 of Set 7 | cabo san lucas
# Processing Record 27 of Set 7 | aransas pass
# Processing Record 28 of Set 7 | aswan
# Processing Record 29 of Set 7 | russkaya polyana
# Processing Record 30 of Set 7 | clacton-on-sea
# Processing Record 31 of Set 7 | ulaangom
# Processing Record 32 of Set 7 | pleasanton
# Processing Record 33 of Set 7 | makakilo city
# Processing Record 34 of Set 7 | san vicente
# Processing Record 35 of Set 7 | antofagasta
# Processing Record 36 of Set 7 | lesnoy
# Processing Record 37 of Set 7 | tiksi
# Processing Record 38 of Set 7 | baiyin
# Processing Record 39 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 7 | krasnoarmeysk
# Processing Record 41 of Set 7 | tongchuan
# Processing Record 42 of Set 7 | tsaratanana
# Processing Record 43 of Set 7 | barinas
# Processing Record 44 of Set 7 | necochea
# Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 7 | camacha
# Processing Record 47 of Set 7 | jinchang
# Processing Record 48 of Set 7 | tambacounda
# Processing Record 49 of Set 7 | carnarvon
# Processing Record 50 of Set 7 | manbij
# Processing Record 1 of Set 8 | merauke
# Processing Record 2 of Set 8 | pombas
# Processing Record 3 of Set 8 | alta floresta
# Processing Record 4 of Set 8 | broken hill
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | atmakur
# Processing Record 7 of Set 8 | staryy nadym
# Processing Record 8 of Set 8 | port-cartier
# Processing Record 9 of Set 8 | polyarnyy
# Processing Record 10 of Set 8 | sept-iles
# Processing Record 11 of Set 8 | lamu
# Processing Record 12 of Set 8 | iskateley
# Processing Record 13 of Set 8 | sao filipe
# Processing Record 14 of Set 8 | loukhi
# Processing Record 15 of Set 8 | qiyang
# Processing Record 16 of Set 8 | strezhevoy
# Processing Record 17 of Set 8 | danielskuil
# Processing Record 18 of Set 8 | key largo
# Processing Record 19 of Set 8 | faya
# Processing Record 20 of Set 8 | jinxiang
# Processing Record 21 of Set 8 | mahebourg
# Processing Record 22 of Set 8 | axim
# Processing Record 23 of Set 8 | hofn
# Processing Record 24 of Set 8 | purranque
# Processing Record 25 of Set 8 | souillac
# Processing Record 26 of Set 8 | isa khel
# Processing Record 27 of Set 8 | nha trang
# Processing Record 28 of Set 8 | taksimo
# Processing Record 29 of Set 8 | bonnyville
# Processing Record 30 of Set 8 | tual
# Processing Record 31 of Set 8 | bengkulu
# Processing Record 32 of Set 8 | cockburn town
# Processing Record 33 of Set 8 | sangar
# Processing Record 34 of Set 8 | darhan
# Processing Record 35 of Set 8 | bealanana
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | bubaque
# Processing Record 38 of Set 8 | teguldet
# Processing Record 39 of Set 8 | turukhansk
# Processing Record 40 of Set 8 | berezovyy
# Processing Record 41 of Set 8 | tiarei
# Processing Record 42 of Set 8 | mount gambier
# Processing Record 43 of Set 8 | mata
# Processing Record 44 of Set 8 | kuusamo
# Processing Record 45 of Set 8 | itaquyry
# Processing Record 46 of Set 8 | oskemen
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | plainview
# Processing Record 49 of Set 8 | mkushi
# Processing Record 50 of Set 8 | maroua
# Processing Record 1 of Set 9 | umm kaddadah
# Processing Record 2 of Set 9 | ouanaminthe
# Processing Record 3 of Set 9 | umm lajj
# Processing Record 4 of Set 9 | belomorsk
# Processing Record 5 of Set 9 | rio gallegos
# Processing Record 6 of Set 9 | pasinler
# Processing Record 7 of Set 9 | itarantim
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | tomatlan
# Processing Record 11 of Set 9 | lompoc
# Processing Record 12 of Set 9 | stokmarknes
# Processing Record 13 of Set 9 | poprad
# Processing Record 14 of Set 9 | wenatchee
# Processing Record 15 of Set 9 | sucua
# Processing Record 16 of Set 9 | price
# Processing Record 17 of Set 9 | santa cruz de tenerife
# Processing Record 18 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 9 | wenling
# Processing Record 20 of Set 9 | saint-denis
# Processing Record 21 of Set 9 | buraydah
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | peterhead
# Processing Record 24 of Set 9 | la crosse
# Processing Record 25 of Set 9 | nimaparha
# Processing Record 26 of Set 9 | pringsewu
# Processing Record 27 of Set 9 | tatawin
# Processing Record 28 of Set 9 | awbari
# Processing Record 29 of Set 9 | nelson bay
# Processing Record 30 of Set 9 | ust-uda
# Processing Record 31 of Set 9 | east london
# Processing Record 32 of Set 9 | vestmannaeyjar
# Processing Record 33 of Set 9 | porto novo
# Processing Record 34 of Set 9 | svetlyy
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | panacan
# Processing Record 37 of Set 9 | pinega
# Processing Record 38 of Set 9 | mar del plata
# Processing Record 39 of Set 9 | medicine hat
# Processing Record 40 of Set 9 | barao de melgaco
# Processing Record 41 of Set 9 | rognan
# Processing Record 42 of Set 9 | jobner
# Processing Record 43 of Set 9 | adamovka
# Processing Record 44 of Set 9 | fuzhou
# Processing Record 45 of Set 9 | bonfim
# Processing Record 46 of Set 9 | montrose
# Processing Record 47 of Set 9 | vrangel
# Processing Record 48 of Set 9 | clyde river
# Processing Record 49 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 9 | severobaykalsk
# Processing Record 1 of Set 10 | novaya ladoga
# Processing Record 2 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 10 | davila
# Processing Record 4 of Set 10 | manokwari
# Processing Record 5 of Set 10 | socond
# Processing Record 6 of Set 10 | kajiado
# Processing Record 7 of Set 10 | finnsnes
# Processing Record 8 of Set 10 | dingle
# Processing Record 9 of Set 10 | lakatoro
# Processing Record 10 of Set 10 | vedasandur
# Processing Record 11 of Set 10 | moose factory
# Processing Record 12 of Set 10 | sladkovo
# Processing Record 13 of Set 10 | anloga
# Processing Record 14 of Set 10 | teluknaga
# Processing Record 15 of Set 10 | kuching
# Processing Record 16 of Set 10 | belz
# Processing Record 17 of Set 10 | kutum
# Processing Record 18 of Set 10 | inhambane
# Processing Record 19 of Set 10 | peace river
# Processing Record 20 of Set 10 | kununurra
# Processing Record 21 of Set 10 | thibodaux
# Processing Record 22 of Set 10 | santiago del estero
# Processing Record 23 of Set 10 | yakeshi
# Processing Record 24 of Set 10 | dombarovskiy
# Processing Record 25 of Set 10 | andzhiyevskiy
# Processing Record 26 of Set 10 | sitka
# Processing Record 27 of Set 10 | south sioux city
# Processing Record 28 of Set 10 | xuddur
# Processing Record 29 of Set 10 | ulladulla
# Processing Record 30 of Set 10 | macklin
# Processing Record 31 of Set 10 | sinnamary
# Processing Record 32 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 10 | talnakh
# Processing Record 34 of Set 10 | provideniya
# Processing Record 35 of Set 10 | bethanien
# Processing Record 36 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 37 of Set 10 | san jeronimo
# Processing Record 38 of Set 10 | hvide sande
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | homer
# Processing Record 41 of Set 10 | bardiyah
# Processing Record 42 of Set 10 | nuuk
# Processing Record 43 of Set 10 | shitanjing
# Processing Record 44 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 10 | pierre
# Processing Record 46 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 10 | kuantan
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | makubetsu
# Processing Record 50 of Set 10 | colares
# Processing Record 1 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 11 | naryan-mar
# Processing Record 3 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 11 | meadow lake
# Processing Record 5 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 11 | kaeo
# Processing Record 7 of Set 11 | constitucion
# Processing Record 8 of Set 11 | guanare
# Processing Record 9 of Set 11 | guajara-mirim
# City not found. Skipping...
# Processing Record 10 of Set 11 | ilhabela
# Processing Record 11 of Set 11 | taoudenni
# Processing Record 12 of Set 11 | sukpak
# Processing Record 13 of Set 11 | inverness
# Processing Record 14 of Set 11 | alice springs
# Processing Record 15 of Set 11 | boguchany
# Processing Record 16 of Set 11 | rincon
# Processing Record 17 of Set 11 | auki
# Processing Record 18 of Set 11 | iberia
# Processing Record 19 of Set 11 | chenzhou
# Processing Record 20 of Set 11 | namatanai
# Processing Record 21 of Set 11 | burriana
# Processing Record 22 of Set 11 | beloha
# Processing Record 23 of Set 11 | hasaki
# Processing Record 24 of Set 11 | khani
# Processing Record 25 of Set 11 | hulja
# Processing Record 26 of Set 11 | grandview
# Processing Record 27 of Set 11 | dubai
# Processing Record 28 of Set 11 | grindavik
# Processing Record 29 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 11 | manaure
# Processing Record 31 of Set 11 | college place
# Processing Record 32 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 11 | north myrtle beach
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | opuwo
# Processing Record 36 of Set 11 | kavieng
# Processing Record 37 of Set 11 | ayorou
# Processing Record 38 of Set 11 | dongling
# Processing Record 39 of Set 11 | lesosibirsk
# Processing Record 40 of Set 11 | amberley
# Processing Record 41 of Set 11 | qasigiannguit
# Processing Record 42 of Set 11 | sabang
# Processing Record 43 of Set 11 | gadwal
# Processing Record 44 of Set 11 | beira
# Processing Record 45 of Set 11 | ribeira brava
# Processing Record 46 of Set 11 | morant bay
# Processing Record 47 of Set 11 | olean
# Processing Record 48 of Set 11 | puerto leguizamo
# Processing Record 49 of Set 11 | oranjemund
# Processing Record 50 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 1 of Set 12 | soderhamn
# Processing Record 2 of Set 12 | batagay-alyta
# Processing Record 3 of Set 12 | brae
# Processing Record 4 of Set 12 | aklavik
# Processing Record 5 of Set 12 | san luis
# Processing Record 6 of Set 12 | baruun-urt
# Processing Record 7 of Set 12 | college
# Processing Record 8 of Set 12 | zastron
# Processing Record 9 of Set 12 | gambela
# Processing Record 10 of Set 12 | fare
# Processing Record 11 of Set 12 | hovd
# Processing Record 12 of Set 12 | kushiro
# Processing Record 13 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | dwarka
# Processing Record 15 of Set 12 | quatre cocos
# Processing Record 16 of Set 12 | bagua grande
# Processing Record 17 of Set 12 | khorixas
# Processing Record 18 of Set 12 | hwange
# Processing Record 19 of Set 12 | aktau
# Processing Record 20 of Set 12 | tefe
# Processing Record 21 of Set 12 | burgeo
# Processing Record 22 of Set 12 | belmonte
# Processing Record 23 of Set 12 | harrison
# Processing Record 24 of Set 12 | drezna
# Processing Record 25 of Set 12 | great falls
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 12 | smithers
# Processing Record 29 of Set 12 | jishou
# Processing Record 30 of Set 12 | belgrade
# Processing Record 31 of Set 12 | severo-yeniseyskiy
# Processing Record 32 of Set 12 | tura
# Processing Record 33 of Set 12 | afikpo
# Processing Record 34 of Set 12 | rajanpur
# Processing Record 35 of Set 12 | kapit
# Processing Record 36 of Set 12 | maceio
# Processing Record 37 of Set 12 | progreso
# Processing Record 38 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 39 of Set 12 | trindade
# Processing Record 40 of Set 12 | puerto escondido
# Processing Record 41 of Set 12 | pennagaram
# Processing Record 42 of Set 12 | iquitos
# Processing Record 43 of Set 12 | charters towers
# Processing Record 44 of Set 12 | tyulyachi
# Processing Record 45 of Set 12 | cuxhaven
# Processing Record 46 of Set 12 | zaozerne
# Processing Record 47 of Set 12 | rawson
# Processing Record 48 of Set 12 | roza
# Processing Record 49 of Set 12 | boma
# Processing Record 50 of Set 12 | barreirinhas
# Processing Record 1 of Set 13 | saint-georges
# Processing Record 2 of Set 13 | ardakan
# Processing Record 3 of Set 13 | cagliari
# Processing Record 4 of Set 13 | qui nhon
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | erzurum
# Processing Record 7 of Set 13 | dogondoutchi
# Processing Record 8 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 9 of Set 13 | altay
# Processing Record 10 of Set 13 | naze
# Processing Record 11 of Set 13 | burnie
# Processing Record 12 of Set 13 | salinas
# Processing Record 13 of Set 13 | lobez
# Processing Record 14 of Set 13 | elko
# Processing Record 15 of Set 13 | lubango
# Processing Record 16 of Set 13 | tabuk
# Processing Record 17 of Set 13 | bosaso
# Processing Record 18 of Set 13 | patan
# Processing Record 19 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 13 | luderitz
# Processing Record 21 of Set 13 | bellinge
# Processing Record 22 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 23 of Set 13 | birjand
# Processing Record 24 of Set 13 | bilibino
# Processing Record 25 of Set 13 | lang son
# Processing Record 26 of Set 13 | henties bay
# Processing Record 27 of Set 13 | goroka
# Processing Record 28 of Set 13 | akureyri
# Processing Record 29 of Set 13 | salamiyah
# Processing Record 30 of Set 13 | winnemucca
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | anadyr
# Processing Record 33 of Set 13 | campo formoso
# Processing Record 34 of Set 13 | tooele
# Processing Record 35 of Set 13 | miramar
# Processing Record 36 of Set 13 | fairbanks
# Processing Record 37 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 13 | luwuk
# Processing Record 39 of Set 13 | long beach
# Processing Record 40 of Set 13 | sarakhs
# Processing Record 41 of Set 13 | shingu
# Processing Record 42 of Set 13 | husavik
# Processing Record 43 of Set 13 | vila franca do campo
# Processing Record 44 of Set 13 | mizan teferi
# Processing Record 45 of Set 13 | afua
# Processing Record 46 of Set 13 | boyolangu
# Processing Record 47 of Set 13 | kozan
# Processing Record 48 of Set 13 | yeniseysk
# Processing Record 49 of Set 13 | shimoda
# Processing Record 50 of Set 13 | westport
# Processing Record 1 of Set 14 | dubbo
# Processing Record 2 of Set 14 | denpasar
# Processing Record 3 of Set 14 | leningradskiy
# Processing Record 4 of Set 14 | olga
# Processing Record 5 of Set 14 | mochitlan
# City not found. Skipping...
# Processing Record 6 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 7 of Set 14 | kaspiysk
# Processing Record 8 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 14 | youhao
# Processing Record 10 of Set 14 | bobigny
# Processing Record 11 of Set 14 | bilma
# Processing Record 12 of Set 14 | segezha
# Processing Record 13 of Set 14 | sangerhausen
# Processing Record 14 of Set 14 | shache
# Processing Record 15 of Set 14 | zheleznodorozhnyy
# Processing Record 16 of Set 14 | aurora
# Processing Record 17 of Set 14 | andevoranto
# City not found. Skipping...
# Processing Record 18 of Set 14 | tagusao
# Processing Record 19 of Set 14 | cervo
# Processing Record 20 of Set 14 | moron
# Processing Record 21 of Set 14 | dudinka
# Processing Record 22 of Set 14 | cuite
# Processing Record 23 of Set 14 | ukiah
# Processing Record 24 of Set 14 | mahibadhoo
# Processing Record 25 of Set 14 | kosh-agach
# Processing Record 26 of Set 14 | manoel urbano
# Processing Record 27 of Set 14 | senanga
# Processing Record 28 of Set 14 | lulea
# Processing Record 29 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 14 | nuqui
# Processing Record 31 of Set 14 | taltal
# Processing Record 32 of Set 14 | tartki
# City not found. Skipping...
# Processing Record 33 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 14 | morondava
# Processing Record 35 of Set 14 | medea
# Processing Record 36 of Set 14 | jinchengjiang
# City not found. Skipping...
# Processing Record 37 of Set 14 | san policarpo
# Processing Record 38 of Set 14 | londonderry
# Processing Record 39 of Set 14 | cordoba
# Processing Record 40 of Set 14 | lufilufi
# Processing Record 41 of Set 14 | vostok
# Processing Record 42 of Set 14 | phangnga
# Processing Record 43 of Set 14 | tiznit
# Processing Record 44 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 45 of Set 14 | otradnoye
# Processing Record 46 of Set 14 | viedma
# Processing Record 47 of Set 14 | flin flon
# Processing Record 48 of Set 14 | manyana
# Processing Record 49 of Set 14 | walvis bay
# Processing Record 50 of Set 14 | mednogorsk
# Processing Record 1 of Set 15 | hadejia
# Processing Record 2 of Set 15 | fort saint james
# Processing Record 3 of Set 15 | manjacaze
# Processing Record 4 of Set 15 | gladstone
# Processing Record 5 of Set 15 | arman
# Processing Record 6 of Set 15 | jaen
# Processing Record 7 of Set 15 | ostersund
# Processing Record 8 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 9 of Set 15 | yenagoa
# Processing Record 10 of Set 15 | bulgan
# Processing Record 11 of Set 15 | noumea
# Processing Record 12 of Set 15 | port victoria
# Processing Record 13 of Set 15 | anapskaya
# Processing Record 14 of Set 15 | lata
# Processing Record 15 of Set 15 | rendsburg
# Processing Record 16 of Set 15 | archidona
# Processing Record 17 of Set 15 | high level
# Processing Record 18 of Set 15 | vila
# Processing Record 19 of Set 15 | pilar
# Processing Record 20 of Set 15 | nizwa
# Processing Record 21 of Set 15 | lima
# Processing Record 22 of Set 15 | berdigestyakh
# Processing Record 23 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 24 of Set 15 | binga
# Processing Record 25 of Set 15 | iqaluit
# Processing Record 26 of Set 15 | ambon
# Processing Record 27 of Set 15 | okha
# Processing Record 28 of Set 15 | karratha
# Processing Record 29 of Set 15 | san jacinto
# Processing Record 30 of Set 15 | lexington
# Processing Record 31 of Set 15 | thai binh
# Processing Record 32 of Set 15 | sijunjung
# Processing Record 33 of Set 15 | palu
# Processing Record 34 of Set 15 | butajira
# Processing Record 35 of Set 15 | kaitong
# Processing Record 36 of Set 15 | maningrida
# Processing Record 37 of Set 15 | mount isa
# Processing Record 38 of Set 15 | baykit
# Processing Record 39 of Set 15 | kendari
# Processing Record 40 of Set 15 | lazaro cardenas
# Processing Record 41 of Set 15 | perth
# Processing Record 42 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 15 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 15 | poronaysk
# Processing Record 45 of Set 15 | aksakovo
# Processing Record 46 of Set 15 | grimshaw
# Processing Record 47 of Set 15 | zhigansk
# Processing Record 48 of Set 15 | tres arroyos
# Processing Record 49 of Set 15 | ladario
# Processing Record 50 of Set 15 | wellington
# Processing Record 1 of Set 16 | koutsouras
# Processing Record 2 of Set 16 | ballina
# Processing Record 3 of Set 16 | diego de almagro
# Processing Record 4 of Set 16 | bantogon
# Processing Record 5 of Set 16 | myitkyina
# Processing Record 6 of Set 16 | changtu
# Processing Record 7 of Set 16 | warrnambool
# Processing Record 8 of Set 16 | maragheh
# Processing Record 9 of Set 16 | zhezkazgan
# Processing Record 10 of Set 16 | road town
# Processing Record 11 of Set 16 | banda aceh
# Processing Record 12 of Set 16 | tuatapere
# Processing Record 13 of Set 16 | kirakira
# Processing Record 14 of Set 16 | karlskoga
# Processing Record 15 of Set 16 | mattru
# Processing Record 16 of Set 16 | zarubino
# Processing Record 17 of Set 16 | nizhnyaya tavda
# Processing Record 18 of Set 16 | duku
# Processing Record 19 of Set 16 | kieta
# Processing Record 20 of Set 16 | waiouru
# Processing Record 21 of Set 16 | sur
# Processing Record 22 of Set 16 | abaran
# Processing Record 23 of Set 16 | capreol
# Processing Record 24 of Set 16 | mulbagal
# Processing Record 25 of Set 16 | przhevalskoye
# Processing Record 26 of Set 16 | gucheng
# Processing Record 27 of Set 16 | san rafael del sur
# Processing Record 28 of Set 16 | verkhnevilyuysk
# Processing Record 29 of Set 16 | ixtapa
# Processing Record 30 of Set 16 | hualmay
# Processing Record 31 of Set 16 | chake chake
# Processing Record 32 of Set 16 | sioux lookout
# Processing Record 33 of Set 16 | bougouni
# Processing Record 34 of Set 16 | nador
# Processing Record 35 of Set 16 | tilichiki
# Processing Record 36 of Set 16 | maragogi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %%
# Create new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#       City      Lat       Lng Weather Description  Max Temp  Humidity  \
# 0  Labuhan  -6.8844  112.2051       moderate rain     86.92        64
# 1   Hirara  24.8000  125.2833       broken clouds     73.26        83
# 2     Lebu -37.6167  -73.6500           clear sky     51.39        83
# 3  Kismayo  -0.3582   42.5454     overcast clouds     80.13        77
# 4   Tshane -24.0196   21.8684          few clouds     67.39        71
#
#    Cloudiness  Wind Speed Country
# 0          87        5.21      ID
# 1          75       21.85      JP
# 2           7       11.36      CL
# 3          93        3.38      SO
# 4          18       17.18      BW

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 719 non-null    object
#  1   Lat                  719 non-null    float64
#  2   Lng                  719 non-null    float64
#  3   Weather Description  719 non-null    object
#  4   Max Temp             719 non-null    float64
#  5   Humidity             719 non-null    int64
#  6   Cloudiness           719 non-null    int64
#  7   Wind Speed           719 non-null    float64
#  8   Country              719 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 50.7+ KB

# %%
# Rearrange column order
new_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Labuhan      ID  -6.8844  112.2051     86.92        64          87
# 1   Hirara      JP  24.8000  125.2833     73.26        83          75
# 2     Lebu      CL -37.6167  -73.6500     51.39        83           7
# 3  Kismayo      SO  -0.3582   42.5454     80.13        77          93
# 4   Tshane      BW -24.0196   21.8684     67.39        71          18
#
#    Wind Speed Weather Description
# 0        5.21       moderate rain
# 1       21.85       broken clouds
# 2       11.36           clear sky
# 3        3.38     overcast clouds
# 4       17.18          few clouds

# %%
# Save as CSV
output_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_file, index_label = "City_ID")
